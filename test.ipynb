# %%
import pandas as pd

# %%
df = pd.read_parquet("/Users/christinadong/Documents/Gen AI/Final_Project_Applied_GenAI/data/processed/clean_products_clothing.parquet")

# %%
df
# Out:
#                                    id  \
# 0    40d3cd16b41970ae6872e914aecf2c8e
# 1    171c7524e8cf032d08d1315f3a538345
# 2    82be0dec20a875155a066440ef111310
# 3    5483f67f50a97a8dd7f404f80eab75e1
# 4    83e5bb2c78aa73a08f2363e66fcd9e1b
# ..                                ...
# 625  02a033f5a17a277a59e2eeb0d8c85894
# 626  f53fc55470d36bc5cb675eb665631b64
# 627  9351e0e4a751fc75b9367e1ebc7d193e
# 628  68f93eb7852263685cb7259ff453db05
# 629  59ac32c72fa3b1a0cb02135bdbb2ec3c
#
#                                                  title  brand  \
# 0    Rubie's Child's Pokemon Deluxe Pikachu Costume...    NaN
# 1    Forum Novelties Union Officer Child's Costume,...    NaN
# 2    Marvel Avengers Assemble Captain America Costu...    NaN
# 3    Great Eastern Entertainment Boys Attack On Tit...    NaN
# 4                     Rubie's Adult 2-Tone Costume Wig    NaN
# ..                                                 ...    ...
# 625  Underwraps Toddler's Teddy Bear Belly Babies C...    NaN
# ...

# %%
df_raw = pd.read_csv("/Users/christinadong/Documents/Gen AI/Final_Project_Applied_GenAI/data/raw/marketing_sample_for_amazon_com-ecommerce__20200101_20200131__10k_data.csv")

# %%
df_raw
# Out:
#                                 Uniq Id  \
# 0      4c69b61db1fc16e7013b43fc926e502d
# 1      66d49bbed043f5be260fa9f7fbff5957
# 2      2c55cae269aebf53838484b0d7dd931a
# 3      18018b6bc416dab347b1b7db79994afa
# 4      e04b990e95bf73bbe6a3fa09785d7cd0
# ...                                 ...
# 9997   1a22f23576bfdfe5ed6c887dc117aab6
# 9998   e11514dcf1f087887cd5ea0bd646d1fc
# 9999   c00301a38560da2abc89c1f86ce4b267
# 10000  c2928dbf9796ceba44863a2736afb405
# 10001  2bb94aefc3467ed83860e0e2712d5f10
#
#                                             Product Name  Brand Name  Asin  \
# 0      DB Longboards CoreFlex Crossbow 41" Bamboo Fib...         NaN   NaN
# 1      Electronic Snap Circuits Mini Kits Classpack, ...         NaN   NaN
# 2      3Doodler Create Flexy 3D Printing Filament Ref...         NaN   NaN
# 3      Guillow Airplane Design Studio with Travel Cas...         NaN   NaN
# 4                       Woodstock- Collage 500 pc Puzzle         NaN   NaN
# ...

# %%
df_raw["Image"]
# Out:
# 0        https://images-na.ssl-images-amazon.com/images...
# 1        https://images-na.ssl-images-amazon.com/images...
# 2        https://images-na.ssl-images-amazon.com/images...
# 3        https://images-na.ssl-images-amazon.com/images...
# 4        https://images-na.ssl-images-amazon.com/images...
#                                ...
# 9997     https://images-na.ssl-images-amazon.com/images...
# 9998     https://images-na.ssl-images-amazon.com/images...
# 9999     https://images-na.ssl-images-amazon.com/images...
# 10000    https://images-na.ssl-images-amazon.com/images...
# 10001    https://images-na.ssl-images-amazon.com/images...
# Name: Image, Length: 10002, dtype: object

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10002 entries, 0 to 10001
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Uniq Id                10002 non-null  object
#  1   Product Name           10002 non-null  object
#  2   Brand Name             0 non-null      float64
#  3   Asin                   0 non-null      float64
#  4   Category               9172 non-null   object
#  5   Upc Ean Code           34 non-null     object
#  6   List Price             0 non-null      float64
#  7   Selling Price          9895 non-null   object
#  8   Quantity               0 non-null      float64
#  9   Model Number           8230 non-null   object
#  10  About Product          9729 non-null   object
#  11  Product Specification  8370 non-null   object
#  12  Technical Details      9212 non-null   object
#  13  Shipping Weight        8864 non-null   object
# ...
